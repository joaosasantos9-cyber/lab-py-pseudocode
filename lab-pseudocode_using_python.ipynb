# %% [markdown]
# # LAB | Pseudocode Using Python
#
# ## Overview
#
# This exercise will help you practice writing pseudocode and translating it into Python code. Pseudocode is a way to describe algorithms in a human-readable format, which can then be implemented in programming languages.

# %% [markdown]
# ### Exercise 1: Multiply Two Numbers
#
# Write a pseudocode to read two numbers and multiply them together. Then, write the equivalent Python code.

# %% [markdown]
# ```
# START
#   READ number1
#   READ number2
#   SET result = number1 * number2
#   PRINT result
# END
# ```

# %%
# Read two numbers from the user (input() always returns a string, so we convert to float)
number1 = float(input("Enter the first number: "))
number2 = float(input("Enter the second number: "))

# Multiply the two numbers
result = number1 * number2

# Display the result
print(f"{number1} x {number2} = {result}")

# %% [markdown]
# ### Exercise 2: Check Even or Odd
#
# Write pseudocode that checks if a number is even or odd and prints the result. Then, write the equivalent Python code.

# %% [markdown]
# ```
# START
#   READ number
#   IF number MOD 2 == 0 THEN
#     PRINT "Even"
#   ELSE
#     PRINT "Odd"
#   END IF
# END
# ```

# %%
# Read a number from the user
number = int(input("Enter a number: "))

# The modulo operator (%) returns the remainder of a division
# If number % 2 == 0, there is no remainder -> the number is even
# Otherwise, there is a remainder of 1 -> the number is odd
if number % 2 == 0:
    print(f"{number} is Even")
else:
    print(f"{number} is Odd")

# %% [markdown]
# ### Exercise 3: Sum of First N Natural Numbers
#
# Write pseudocode to calculate the sum of the first N natural numbers. Then, write the equivalent Python code.

# %% [markdown]
# ```
# START
#   READ N
#   SET total = 0
#   FOR i FROM 1 TO N DO
#     SET total = total + i
#   END FOR
#   PRINT total
# END
# ```

# %%
# Read how many natural numbers to sum
N = int(input("Enter N: "))

# Initialize the accumulator at 0
total = 0

# Loop from 1 to N (inclusive) and add each number to total
# range(1, N+1) generates: 1, 2, 3, ..., N
for i in range(1, N + 1):
    total += i  # same as: total = total + i

# Display the result
print(f"Sum of first {N} natural numbers = {total}")

# Alternative one-liner using Python's built-in sum() function:
# total = sum(range(1, N + 1))

# %% [markdown]
# ### Exercise 4: Find Maximum of Three Numbers
#
# Write pseudocode that finds the maximum of three numbers entered by the user. Then, write the equivalent Python code.

# %% [markdown]
# ```
# START
#   READ a, b, c
#   IF a >= b AND a >= c THEN
#     SET maximum = a
#   ELSE IF b >= a AND b >= c THEN
#     SET maximum = b
#   ELSE
#     SET maximum = c
#   END IF
#   PRINT maximum
# END
# ```

# %%
# Read three numbers from the user
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
c = float(input("Enter the third number: "))

# Compare the three numbers to find the maximum
if a >= b and a >= c:
    maximum = a
elif b >= a and b >= c:
    maximum = b
else:
    maximum = c

# Display the result
print(f"The maximum of {a}, {b}, and {c} is: {maximum}")

# Alternative using Python's built-in max() function:
# maximum = max(a, b, c)

# %% [markdown]
# ### Exercise 5: Count Vowels in a String
#
# Write pseudocode to count the number of vowels in a given string and print the count. Then, write the equivalent Python code.

# %% [markdown]
# ```
# START
#   READ text
#   SET vowels = "aeiouAEIOU"
#   SET count = 0
#   FOR each character IN text DO
#     IF character IN vowels THEN
#       SET count = count + 1
#     END IF
#   END FOR
#   PRINT count
# END
# ```

# %%
# Read a string from the user
text = input("Enter a string: ")

# Define all vowels (both uppercase and lowercase)
vowels = "aeiouAEIOU"

# Initialize the counter
count = 0

# Loop through each character and check if it is a vowel
for char in text:
    if char in vowels:  # 'in' checks if char exists in the vowels string
        count += 1

# Display the result
print(f"Number of vowels in '{text}': {count}")

# Alternative one-liner using a generator expression:
# count = sum(1 for char in text if char in vowels)

# %% [markdown]
# ## Bonus Exercises
#
# ### Bonus Exercise 6: Reverse a String
#
# Write pseudocode to reverse a given string and print it out.

# %% [markdown]
# ```
# START
#   READ text
#   SET reversed_text = ""
#   FOR i FROM length(text)-1 DOWN TO 0 DO
#     SET reversed_text = reversed_text + text[i]
#   END FOR
#   PRINT reversed_text
# END
# ```

# %%
# Read a string from the user
text = input("Enter a string: ")

# Method 1: Manual loop (matches the pseudocode logic)
# Start with an empty string and append characters from the end
reversed_text = ""
for i in range(len(text) - 1, -1, -1):  # range(start, stop, step=-1)
    reversed_text += text[i]

print(f"Reversed: {reversed_text}")

# Method 2: Python slicing (more Pythonic)
# text[::-1] means: start from end, go to beginning, step -1
print(f"Reversed (slicing): {text[::-1]}")

# %% [markdown]
# ### Bonus Exercise 7: Print Multiplication Table of a Number
#
# Write pseudocode to print the multiplication table of a given number up to 10.

# %% [markdown]
# ```
# START
#   READ number
#   FOR i FROM 1 TO 10 DO
#     PRINT number, "x", i, "=", number * i
#   END FOR
# END
# ```

# %%
# Read the number whose multiplication table we want to print
number = int(input("Enter a number: "))

print(f"\nMultiplication table of {number}:")

# Loop from 1 to 10 (inclusive) and print each multiplication
for i in range(1, 11):  # range(1, 11) generates 1, 2, 3, ..., 10
    result = number * i
    print(f"{number} x {i:2} = {result}")
    # :2 pads 'i' to 2 characters wide for aligned output

# %% [markdown]
# ### Bonus Exercise 8: Count Words in a String
#
# Write pseudocode that counts the words in a given string and prints the result.

# %% [markdown]
# ```
# START
#   READ text
#   SET words = SPLIT text BY " "
#   SET count = LENGTH of words
#   PRINT count
# END
# ```

# %%
# Read a string from the user
text = input("Enter a sentence: ")

# str.split() splits the string by whitespace by default
# It also handles multiple consecutive spaces correctly
# Example: "Hello   world".split() -> ['Hello', 'world']
words = text.split()

# Count the number of words in the resulting list
count = len(words)

# Display the result
print(f"Number of words: {count}")
print(f"Words found: {words}")

# %% [markdown]
# ### Bonus Exercise 9: Find Factorial of a Number
#
# Write pseudocode that calculates the factorial of a given positive integer.

# %% [markdown]
# ```
# START
#   READ N
#   IF N < 0 THEN
#     PRINT "Factorial is not defined for negative numbers"
#   ELSE
#     SET factorial = 1
#     FOR i FROM 1 TO N DO
#       SET factorial = factorial * i
#     END FOR
#     PRINT factorial
#   END IF
# END
# ```

# %%
# Read a positive integer from the user
N = int(input("Enter a positive integer: "))

# Factorial is only defined for non-negative integers
if N < 0:
    print("Factorial is not defined for negative numbers.")
else:
    # Initialize factorial to 1 (0! and 1! are both 1)
    factorial = 1

    # Multiply from 1 up to N (inclusive)
    # Example for N=5: 1 * 2 * 3 * 4 * 5 = 120
    for i in range(1, N + 1):
        factorial *= i  # same as: factorial = factorial * i

    print(f"{N}! = {factorial}")

# Alternative using Python's math module:
# import math
# print(math.factorial(N))

# %% [markdown]
# ### Bonus Exercise 10: FizzBuzz Problem
#
# Write pseudocode for the FizzBuzz problem where you print numbers from 1 to N but replace multiples of three with "Fizz" and multiples of five with "Buzz".

# %% [markdown]
# ```
# START
#   READ N
#   FOR i FROM 1 TO N DO
#     IF i MOD 3 == 0 AND i MOD 5 == 0 THEN
#       PRINT "FizzBuzz"
#     ELSE IF i MOD 3 == 0 THEN
#       PRINT "Fizz"
#     ELSE IF i MOD 5 == 0 THEN
#       PRINT "Buzz"
#     ELSE
#       PRINT i
#     END IF
#   END FOR
# END
# ```

# %%
# Read the upper limit from the user
N = int(input("Enter N: "))

# Loop from 1 to N (inclusive)
for i in range(1, N + 1):

    # IMPORTANT: check FizzBuzz (divisible by both 3 and 5) FIRST
    # If we checked 3 or 5 individually first, we'd print 'Fizz' or 'Buzz'
    # instead of 'FizzBuzz' for multiples of 15
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
